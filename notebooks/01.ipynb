# %%
# ==========================================================
#  NOTEBOOK 01 — PRÉ-PROCESSAMENTO DOS BOARDGAMES
# ==========================================================

from pyspark.sql import SparkSession
from pyspark.sql.functions import col
import pyspark.sql.functions as F
from pyspark.sql.window import Window
import json

# ----------------------------------------------------------
# Criar sessão Spark
# ----------------------------------------------------------
spark = SparkSession.builder.appName("BoardGames01").getOrCreate()

# ----------------------------------------------------------
# 1) Carregar dataset JSON
# ----------------------------------------------------------
with open("/app/dados/boardgames_100.json") as f:
    games_data = json.load(f)

df = spark.createDataFrame(games_data)

print("Schema original:")
df.printSchema()
df.show(5, truncate=False)

# ----------------------------------------------------------
# 2) Limpeza e padronização de colunas
# ----------------------------------------------------------
df_clean = df.select(
    col("id").cast("long"),
    col("title"),
    col("types"),
    col("rating")["rating"].alias("rating").cast("double"),
    col("rating")["num_of_reviews"].alias("num_reviews").cast("int"),
    F.size(col("recommendations")["fans_liked"]).alias("recommendations")
)

print("\nSchema após limpeza:")
df_clean.printSchema()
df_clean.show(10, truncate=False)

# ----------------------------------------------------------
# 3) Criar os NODES (jogos)
# ----------------------------------------------------------
nodes = df_clean.select(
    col("id").alias("nodeId"),
    "title",
    "rating",
    "num_reviews"
)

print("\nPreview dos nodes:")
nodes.show(10, truncate=False)

# ----------------------------------------------------------
# 4) Criar EDGES com similaridade de rating
# ----------------------------------------------------------
windowSpec = Window.orderBy("rating")

ranked = df_clean.withColumn("rank", F.row_number().over(windowSpec))

edges = (
    ranked.alias("a")
    .join(
        ranked.alias("b"),
        (F.abs(F.col("a.rating") - F.col("b.rating")) < 0.35) &
        (F.col("a.id") != F.col("b.id"))
    )
    .select(
        F.col("a.id").alias("src"),
        F.col("b.id").alias("dst")
    )
    .limit(500)
)

print("\nPreview dos edges:")
edges.show(20)

# ----------------------------------------------------------
# 5) Salvar nodes e edges como CSVs
# ----------------------------------------------------------
nodes_path = "/app/dados/nodes.csv"
edges_path = "/app/dados/edges.csv"

nodes.coalesce(1).write.csv(nodes_path, header=True, mode="overwrite")
edges.coalesce(1).write.csv(edges_path, header=True, mode="overwrite")

print(f"\nnodes.csv salvo em: {nodes_path}")
print(f"edges.csv salvo em: {edges_path}")

print("\nNotebook 01 finalizado com sucesso!")
# Out:
# Schema original:
# root
#  |-- credit: map (nullable = true)
#  |    |-- key: string
#  |    |-- value: array (valueContainsNull = true)
#  |    |    |-- element: map (containsNull = true)
#  |    |    |    |-- key: string
#  |    |    |    |-- value: long (valueContainsNull = true)
#  |-- id: long (nullable = true)
#  |-- maxplayers: long (nullable = true)
#  |-- maxplaytime: long (nullable = true)
#  |-- minage: long (nullable = true)
#  |-- minplayers: long (nullable = true)
#  |-- minplaytime: long (nullable = true)
#  |-- rank: long (nullable = true)
#  |-- rating: map (nullable = true)
#  |    |-- key: string
#  |    |-- value: double (valueContainsNull = true)
#  |-- recommendations: map (nullable = true)
#  |    |-- key: string
#  |    |-- value: array (valueContainsNull = true)
#  |    |    |-- element: long (containsNull = true)
#  |-- title: string (nullable = true)
#  |-- types: map (nullable = true)
#  |    |-- key: string
#  |    |-- value: array (valueContainsNull = true)
#  |    |    |-- element: map (containsNull = true)
#  |    |    |    |-- key: string
#  |    |    |    |-- value: long (valueContainsNull = true)
#  |-- year: long (nullable = true)
#
# +-------------------------------------------------------------------------------------------------+------+----------+-----------+------+----------+-----------+----+-------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----+
# |credit                                                                                           |id    |maxplayers|maxplaytime|minage|minplayers|minplaytime|rank|rating                                     |recommendations                                                                                                                                                                                                                                 |title                            |types                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |year|
# +-------------------------------------------------------------------------------------------------+------+----------+-----------+------+----------+-----------+----+-------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----+
# |{designer -> [{name -> NULL, id -> 69802}]}                                                      |174430|4         |120        |14    |1         |60         |1   |{num_of_reviews -> NULL, rating -> 8.67527}|{fans_liked -> [291457, 205059, 302723, 192135, 316554, 266507, 161936, 245655, 216734, 233247, 253344, 180263, 82222, 221107, 314040, 169786, 167355, 121921, 162886, 269385, 96848, 169426, 146021, 150376, 255984, 209010, 233078, 237182]}  |Gloomhaven                       |{mechanics -> [{name -> NULL, id -> 2689}, {name -> NULL, id -> 2839}, {name -> NULL, id -> 2018}, {name -> NULL, id -> 2857}, {name -> NULL, id -> 2893}, {name -> NULL, id -> 2023}, {name -> NULL, id -> 2854}, {name -> NULL, id -> 3004}, {name -> NULL, id -> 2676}, {name -> NULL, id -> 2040}, {name -> NULL, id -> 2026}, {name -> NULL, id -> 2824}, {name -> NULL, id -> 2975}, {name -> NULL, id -> 2011}, {name -> NULL, id -> 2846}, {name -> NULL, id -> 2028}, {name -> NULL, id -> 2822}, {name -> NULL, id -> 2020}, {name -> NULL, id -> 2819}, {name -> NULL, id -> 2027}, {name -> NULL, id -> 2015}], categories -> [{name -> NULL, id -> 1022}, {name -> NULL, id -> 1020}, {name -> NULL, id -> 1010}, {name -> NULL, id -> 1046}, {name -> NULL, id -> 1047}]}|2017|
# |{designer -> [{name -> NULL, id -> 32887}, {name -> NULL, id -> 32943}, {name -> NULL, id -> 6}]}|224517|4         |120        |14    |2         |60         |2   |{num_of_reviews -> NULL, rating -> 8.65313}|{fans_liked -> [316554, 102794, 182028, 220308, 256916, 175640, 286749, 342942, 142379, 341169, 233398, 276025, 169786, 177736, 124361, 193738, 184267, 247763, 284378, 229853, 125153, 265188, 251247, 167791, 163068, 161533, 237182, 185343]}|Brass: Birmingham                |{mechanics -> [{name -> NULL, id -> 2040}, {name -> NULL, id -> 2902}, {name -> NULL, id -> 2904}, {name -> NULL, id -> 2900}, {name -> NULL, id -> 2081}, {name -> NULL, id -> 2849}, {name -> NULL, id -> 2826}, {name -> NULL, id -> 2897}], categories -> [{name -> NULL, id -> 1021}, {name -> NULL, id -> 1088}, {name -> NULL, id -> 2710}, {name -> NULL, id -> 1011}]}                                                                                                                                                                                                                                                                                                                                                                                                        |2018|
# |{designer -> [{name -> NULL, id -> 442}, {name -> NULL, id -> 378}]}                             |161936|4         |60         |13    |2         |60         |3   |{num_of_reviews -> NULL, rating -> 8.56688}|{fans_liked -> [197376, 291457, 302723, 266507, 198928, 245655, 224037, 244521, 221107, 314040, 181304, 169786, 121921, 162886, 146508, 2511, 201808, 239188, 178900, 30549, 218074, 174430, 156129, 150376, 279537, 209010, 31481, 171131]}    |Pandemic Legacy: Season 1        |{mechanics -> [{name -> NULL, id -> 2001}, {name -> NULL, id -> 2023}, {name -> NULL, id -> 2040}, {name -> NULL, id -> 2824}, {name -> NULL, id -> 2078}, {name -> NULL, id -> 2004}, {name -> NULL, id -> 2008}, {name -> NULL, id -> 2015}], categories -> [{name -> NULL, id -> 1084}, {name -> NULL, id -> 2145}]}                                                                                                                                                                                                                                                                                                                                                                                                                                                                |2015|
# |{designer -> [{name -> NULL, id -> 138517}]}                                                     |342942|4         |150        |14    |1         |90         |4   |{num_of_reviews -> NULL, rating -> 8.56684}|{fans_liked -> [318084, 224517, 316554, 286096, 311193, 246684, 308765, 300322, 312484, 328871, 236457, 341169, 276025, 266810, 164928, 301255, 177736, 193738, 247763, 296151, 229853, 343905, 183394, 265188, 167791, 199792, 279537, 163068]}|Ark Nova                         |{mechanics -> [{name -> NULL, id -> 2875}, {name -> NULL, id -> 2040}, {name -> NULL, id -> 2026}, {name -> NULL, id -> 2902}, {name -> NULL, id -> 2041}, {name -> NULL, id -> 2004}, {name -> NULL, id -> 2819}, {name -> NULL, id -> 3100}, {name -> NULL, id -> 2002}, {name -> NULL, id -> 2015}, {name -> NULL, id -> 2897}], categories -> [{name -> NULL, id -> 1089}, {name -> NULL, id -> 1021}, {name -> NULL, id -> 1084}]}                                                                                                                                                                                                                                                                                                                                                |2021|
# |{designer -> [{name -> NULL, id -> 96049}, {name -> NULL, id -> 6651}, {name -> NULL, id -> 21}]}|233078|6         |480        |14    |3         |240        |5   |{num_of_reviews -> NULL, rating -> 8.6449} |{fans_liked -> [316554, 299659, 285967, 245655, 233247, 181279, 115746, 39463, 155821, 82222, 103343, 127023, 175155, 169786, 167355, 253499, 162886, 205896, 297562, 283355, 174430, 170216, 189932, 167791, 340466, 246900, 187645, 237182]}  |Twilight Imperium: Fourth Edition|{mechanics -> [{name -> NULL, id -> 2838}, {name -> NULL, id -> 2080}, {name -> NULL, id -> 2021}, {name -> NULL, id -> 2072}, {name -> NULL, id -> 2843}, {name -> NULL, id -> 2676}, {name -> NULL, id -> 2026}, {name -> NULL, id -> 2914}, {name -> NULL, id -> 2886}, {name -> NULL, id -> 2011}, {name -> NULL, id -> 2876}, {name -> NULL, id -> 2849}, {name -> NULL, id -> 2008}, {name -> NULL, id -> 2079}, {name -> NULL, id -> 2015}, {name -> NULL, id -> 2897}, {name -> NULL, id -> 2017}], categories -> [{name -> NULL, id -> 1015}, {name -> NULL, id -> 1021}, {name -> NULL, id -> 1020}, {name -> NULL, id -> 1026}, {name -> NULL, id -> 1001}, {name -> NULL, id -> 1016}, {name -> NULL, id -> 1113}, {name -> NULL, id -> 1019}]}                            |2017|
# +-------------------------------------------------------------------------------------------------+------+----------+-----------+------+----------+-----------+----+-------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----+
# only showing top 5 rows
#
#
# Schema após limpeza:
# root
#  |-- id: long (nullable = true)
#  |-- title: string (nullable = true)
#  |-- types: map (nullable = true)
#  |    |-- key: string
#  |    |-- value: array (valueContainsNull = true)
#  |    |    |-- element: map (containsNull = true)
#  |    |    |    |-- key: string
#  |    |    |    |-- value: long (valueContainsNull = true)
#  |-- rating: double (nullable = true)
#  |-- num_reviews: integer (nullable = true)
#  |-- recommendations: integer (nullable = false)
#
# +------+---------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------+-----------+---------------+
# |id    |title                            |types                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |rating |num_reviews|recommendations|
# +------+---------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------+-----------+---------------+
# |174430|Gloomhaven                       |{mechanics -> [{name -> NULL, id -> 2689}, {name -> NULL, id -> 2839}, {name -> NULL, id -> 2018}, {name -> NULL, id -> 2857}, {name -> NULL, id -> 2893}, {name -> NULL, id -> 2023}, {name -> NULL, id -> 2854}, {name -> NULL, id -> 3004}, {name -> NULL, id -> 2676}, {name -> NULL, id -> 2040}, {name -> NULL, id -> 2026}, {name -> NULL, id -> 2824}, {name -> NULL, id -> 2975}, {name -> NULL, id -> 2011}, {name -> NULL, id -> 2846}, {name -> NULL, id -> 2028}, {name -> NULL, id -> 2822}, {name -> NULL, id -> 2020}, {name -> NULL, id -> 2819}, {name -> NULL, id -> 2027}, {name -> NULL, id -> 2015}], categories -> [{name -> NULL, id -> 1022}, {name -> NULL, id -> 1020}, {name -> NULL, id -> 1010}, {name -> NULL, id -> 1046}, {name -> NULL, id -> 1047}]}|8.67527|NULL       |28             |
# |224517|Brass: Birmingham                |{mechanics -> [{name -> NULL, id -> 2040}, {name -> NULL, id -> 2902}, {name -> NULL, id -> 2904}, {name -> NULL, id -> 2900}, {name -> NULL, id -> 2081}, {name -> NULL, id -> 2849}, {name -> NULL, id -> 2826}, {name -> NULL, id -> 2897}], categories -> [{name -> NULL, id -> 1021}, {name -> NULL, id -> 1088}, {name -> NULL, id -> 2710}, {name -> NULL, id -> 1011}]}                                                                                                                                                                                                                                                                                                                                                                                                        |8.65313|NULL       |28             |
# |161936|Pandemic Legacy: Season 1        |{mechanics -> [{name -> NULL, id -> 2001}, {name -> NULL, id -> 2023}, {name -> NULL, id -> 2040}, {name -> NULL, id -> 2824}, {name -> NULL, id -> 2078}, {name -> NULL, id -> 2004}, {name -> NULL, id -> 2008}, {name -> NULL, id -> 2015}], categories -> [{name -> NULL, id -> 1084}, {name -> NULL, id -> 2145}]}                                                                                                                                                                                                                                                                                                                                                                                                                                                                |8.56688|NULL       |28             |
# |342942|Ark Nova                         |{mechanics -> [{name -> NULL, id -> 2875}, {name -> NULL, id -> 2040}, {name -> NULL, id -> 2026}, {name -> NULL, id -> 2902}, {name -> NULL, id -> 2041}, {name -> NULL, id -> 2004}, {name -> NULL, id -> 2819}, {name -> NULL, id -> 3100}, {name -> NULL, id -> 2002}, {name -> NULL, id -> 2015}, {name -> NULL, id -> 2897}], categories -> [{name -> NULL, id -> 1089}, {name -> NULL, id -> 1021}, {name -> NULL, id -> 1084}]}                                                                                                                                                                                                                                                                                                                                                |8.56684|NULL       |28             |
# |233078|Twilight Imperium: Fourth Edition|{mechanics -> [{name -> NULL, id -> 2838}, {name -> NULL, id -> 2080}, {name -> NULL, id -> 2021}, {name -> NULL, id -> 2072}, {name -> NULL, id -> 2843}, {name -> NULL, id -> 2676}, {name -> NULL, id -> 2026}, {name -> NULL, id -> 2914}, {name -> NULL, id -> 2886}, {name -> NULL, id -> 2011}, {name -> NULL, id -> 2876}, {name -> NULL, id -> 2849}, {name -> NULL, id -> 2008}, {name -> NULL, id -> 2079}, {name -> NULL, id -> 2015}, {name -> NULL, id -> 2897}, {name -> NULL, id -> 2017}], categories -> [{name -> NULL, id -> 1015}, {name -> NULL, id -> 1021}, {name -> NULL, id -> 1020}, {name -> NULL, id -> 1026}, {name -> NULL, id -> 1001}, {name -> NULL, id -> 1016}, {name -> NULL, id -> 1113}, {name -> NULL, id -> 1019}]}                            |8.6449 |NULL       |28             |
# |167791|Terraforming Mars                |{mechanics -> [{name -> NULL, id -> 2984}, {name -> NULL, id -> 2912}, {name -> NULL, id -> 2043}, {name -> NULL, id -> 2875}, {name -> NULL, id -> 2040}, {name -> NULL, id -> 2026}, {name -> NULL, id -> 2902}, {name -> NULL, id -> 2004}, {name -> NULL, id -> 2819}, {name -> NULL, id -> 3100}, {name -> NULL, id -> 2686}, {name -> NULL, id -> 2849}, {name -> NULL, id -> 2002}, {name -> NULL, id -> 2828}, {name -> NULL, id -> 2015}, {name -> NULL, id -> 2897}, {name -> NULL, id -> 2874}], categories -> [{name -> NULL, id -> 1021}, {name -> NULL, id -> 1084}, {name -> NULL, id -> 1088}, {name -> NULL, id -> 1016}, {name -> NULL, id -> 1113}, {name -> NULL, id -> 1086}]}                                                                                    |8.39103|NULL       |28             |
# |291457|Gloomhaven: Jaws of the Lion     |{mechanics -> [{name -> NULL, id -> 2689}, {name -> NULL, id -> 2839}, {name -> NULL, id -> 2018}, {name -> NULL, id -> 2893}, {name -> NULL, id -> 2023}, {name -> NULL, id -> 2854}, {name -> NULL, id -> 3004}, {name -> NULL, id -> 2676}, {name -> NULL, id -> 2040}, {name -> NULL, id -> 2026}, {name -> NULL, id -> 2824}, {name -> NULL, id -> 2975}, {name -> NULL, id -> 2846}, {name -> NULL, id -> 2822}, {name -> NULL, id -> 2020}, {name -> NULL, id -> 2819}, {name -> NULL, id -> 2015}], categories -> [{name -> NULL, id -> 1022}, {name -> NULL, id -> 1020}, {name -> NULL, id -> 1010}, {name -> NULL, id -> 1046}, {name -> NULL, id -> 1047}]}                                                                                                                |8.55175|NULL       |28             |
# |187645|Star Wars: Rebellion             |{mechanics -> [{name -> NULL, id -> 2080}, {name -> NULL, id -> 2046}, {name -> NULL, id -> 2021}, {name -> NULL, id -> 2857}, {name -> NULL, id -> 2912}, {name -> NULL, id -> 2901}, {name -> NULL, id -> 2072}, {name -> NULL, id -> 2856}, {name -> NULL, id -> 2850}, {name -> NULL, id -> 2040}, {name -> NULL, id -> 2967}, {name -> NULL, id -> 2902}, {name -> NULL, id -> 2846}, {name -> NULL, id -> 2686}, {name -> NULL, id -> 2019}, {name -> NULL, id -> 2015}, {name -> NULL, id -> 2897}], categories -> [{name -> NULL, id -> 1102}, {name -> NULL, id -> 1047}, {name -> NULL, id -> 1064}, {name -> NULL, id -> 1016}, {name -> NULL, id -> 1113}, {name -> NULL, id -> 1019}]}                                                                                    |8.41817|NULL       |28             |
# |115746|War of the Ring: Second Edition  |{mechanics -> [{name -> NULL, id -> 2080}, {name -> NULL, id -> 2046}, {name -> NULL, id -> 2018}, {name -> NULL, id -> 2857}, {name -> NULL, id -> 2072}, {name -> NULL, id -> 2850}, {name -> NULL, id -> 2040}, {name -> NULL, id -> 2967}, {name -> NULL, id -> 2947}, {name -> NULL, id -> 2070}, {name -> NULL, id -> 2019}, {name -> NULL, id -> 2897}], categories -> [{name -> NULL, id -> 1022}, {name -> NULL, id -> 1010}, {name -> NULL, id -> 1046}, {name -> NULL, id -> 1093}, {name -> NULL, id -> 1086}, {name -> NULL, id -> 1019}]}                                                                                                                                                                                                                                |8.52576|NULL       |28             |
# |162886|Spirit Island                    |{mechanics -> [{name -> NULL, id -> 2839}, {name -> NULL, id -> 2080}, {name -> NULL, id -> 2903}, {name -> NULL, id -> 2018}, {name -> NULL, id -> 2023}, {name -> NULL, id -> 2040}, {name -> NULL, id -> 2011}, {name -> NULL, id -> 2004}, {name -> NULL, id -> 2020}, {name -> NULL, id -> 2819}, {name -> NULL, id -> 2015}, {name -> NULL, id -> 2897}], categories -> [{name -> NULL, id -> 1010}, {name -> NULL, id -> 1046}, {name -> NULL, id -> 1082}, {name -> NULL, id -> 1086}]}                                                                                                                                                                                                                                                                                        |8.36924|NULL       |28             |
# +------+---------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------+-----------+---------------+
# only showing top 10 rows
#
#
# Preview dos nodes:
# +------+---------------------------------+-------+-----------+
# |nodeId|title                            |rating |num_reviews|
# +------+---------------------------------+-------+-----------+
# |174430|Gloomhaven                       |8.67527|NULL       |
# |224517|Brass: Birmingham                |8.65313|NULL       |
# |161936|Pandemic Legacy: Season 1        |8.56688|NULL       |
# |342942|Ark Nova                         |8.56684|NULL       |
# |233078|Twilight Imperium: Fourth Edition|8.6449 |NULL       |
# |167791|Terraforming Mars                |8.39103|NULL       |
# |291457|Gloomhaven: Jaws of the Lion     |8.55175|NULL       |
# |187645|Star Wars: Rebellion             |8.41817|NULL       |
# |115746|War of the Ring: Second Edition  |8.52576|NULL       |
# |162886|Spirit Island                    |8.36924|NULL       |
# +------+---------------------------------+-------+-----------+
# only showing top 10 rows
#
#
# Preview dos edges:
# +------+------+
# |   src|   dst|
# +------+------+
# |174430|224517|
# |174430|161936|
# |174430|342942|
# |174430|233078|
# |174430|167791|
# |174430|291457|
# |174430|187645|
# |174430|115746|
# |174430|162886|
# |174430|220308|
# |174430|316554|
# |224517|174430|
# |224517|161936|
# |224517|342942|
# |224517|233078|
# |224517|167791|
# |224517|291457|
# |224517|187645|
# |224517|115746|
# |224517|162886|
# +------+------+
# only showing top 20 rows
# [Stage 7:===================================================>     (58 + 6) / 64]
# nodes.csv salvo em: /app/dados/nodes.csv
# edges.csv salvo em: /app/dados/edges.csv
#
# Notebook 01 finalizado com sucesso!
